# %% [markdown]
# Aggregating Data with Pandas

# %%
import pandas as pd
# import numpy as py

earthquakesdf = pd.read_csv('earthquakes.csv')
earthquakesdf
# Out:
#        mag magType           time                             place  tsunami  \
# 0     1.35      ml  1539475168010             9km NE of Aguanga, CA        0
# 1     1.29      ml  1539475129610             9km NE of Aguanga, CA        0
# 2     3.42      ml  1539475062610             8km NE of Aguanga, CA        0
# 3     0.44      ml  1539474978070             9km NE of Aguanga, CA        0
# 4     2.16      md  1539474716050             10km NW of Avenal, CA        0
# ...    ...     ...            ...                               ...      ...
# 9327  0.62      md  1537230228060      9km ENE of Mammoth Lakes, CA        0
# 9328  1.00      ml  1537230135130               3km W of Julian, CA        0
# 9329  2.40      md  1537229908180  35km NNE of Hatillo, Puerto Rico        0
# 9330  1.10      ml  1537229545350             9km NE of Aguanga, CA        0
# 9331  0.66      ml  1537228864470             9km NE of Aguanga, CA        0
#
#      parsed_place
# 0      California
# 1      California
# 2      California
# 3      California
# 4      California
# ...           ...
# 9327   California
# 9328   California
# 9329  Puerto Rico
# 9330   California
# 9331   California
#
# [9332 rows x 6 columns]

# %%
#Filtering the column magType to find the 'ml' using query()
earthquakes_ml = earthquakesdf.query('magType == "ml" ')
earthquakes_ml
# Out:
#        mag magType           time                         place  tsunami  \
# 0     1.35      ml  1539475168010         9km NE of Aguanga, CA        0
# 1     1.29      ml  1539475129610         9km NE of Aguanga, CA        0
# 2     3.42      ml  1539475062610         8km NE of Aguanga, CA        0
# 3     0.44      ml  1539474978070         9km NE of Aguanga, CA        0
# 6     1.70      ml  1539473176017  105km W of Talkeetna, Alaska        0
# ...    ...     ...            ...                           ...      ...
# 9325  0.51      ml  1537230344890         4km WNW of Julian, CA        0
# 9326  1.82      ml  1537230230260           4km W of Julian, CA        0
# 9328  1.00      ml  1537230135130           3km W of Julian, CA        0
# 9330  1.10      ml  1537229545350         9km NE of Aguanga, CA        0
# 9331  0.66      ml  1537228864470         9km NE of Aguanga, CA        0
#
#      parsed_place
# 0      California
# 1      California
# 2      California
# 3      California
# 6          Alaska
# ...           ...
# 9325   California
# 9326   California
# 9328   California
# 9330   California
# 9331   California
#
# [6803 rows x 6 columns]

# %%
#Creating bins using the filtered dataset

minMag = int(earthquakesdf['mag'].min())
maxMag = int(earthquakesdf['mag'].max())

bins = [i for i in range(minMag, maxMag + 2)]
bins
# Out:
# [-1, 0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
#Creating the bins for min and max
magCounts = pd.cut(earthquakesdf['mag'], bins= bins, right= False).value_counts()
magCounts
# Out:
# mag
# [1, 2)     3827
# [0, 1)     2802
# [2, 3)     1277
# [4, 5)      536
# [-1, 0)     477
# [3, 4)      247
# [5, 6)      139
# [6, 7)       10
# [7, 8)        2
# Name: count, dtype: int64

# %%
fngCsv = pd.read_csv('faang.csv', parse_dates=['date'])
fngCsv .set_index('date', inplace= True)
fngCsv
# Out:
#            ticker     open     high        low    close    volume
# date
# 2018-01-02     FB   177.68   181.58   177.5500   181.42  18151903
# 2018-01-03     FB   181.88   184.78   181.3300   184.67  16886563
# 2018-01-04     FB   184.90   186.21   184.0996   184.33  13880896
# 2018-01-05     FB   185.59   186.90   184.9300   186.85  13574535
# 2018-01-08     FB   187.20   188.90   186.3300   188.28  17994726
# ...           ...      ...      ...        ...      ...       ...
# 2018-12-24   GOOG   973.90  1003.54   970.1100   976.22   1590328
# 2018-12-26   GOOG   989.01  1040.00   983.0000  1039.46   2373270
# 2018-12-27   GOOG  1017.15  1043.89   997.0000  1043.88   2109777
# 2018-12-28   GOOG  1049.62  1055.56  1033.1000  1037.08   1413772
# 2018-12-31   GOOG  1050.96  1052.70  1023.5900  1035.61   1493722
#
# [1255 rows x 6 columns]

# %%
# Grouping by 'ticker' and resampling to monthly end frequency
resmpled=fngCsv.resample('ME').first()
resmpled
# Out:
#            ticker     open      high      low   close    volume
# date
# 2018-01-31     FB  177.680  181.5800  177.550  181.42  18151903
# 2018-02-28     FB  188.220  195.3200  187.890  193.09  54211293
# 2018-03-31     FB  179.010  180.1200  174.410  175.94  23201626
# 2018-04-30     FB  157.810  159.2000  154.111  155.39  36795991
# 2018-05-31     FB  172.000  174.0200  170.230  173.86  26025932
# 2018-06-30     FB  193.065  194.5492  192.070  193.99  17307245
# 2018-07-31     FB  193.370  197.4500  192.220  197.36  13961578
# 2018-08-31     FB  173.930  175.0800  170.900  171.65  34042109
# 2018-09-30     FB  173.500  173.8900  168.800  171.16  29808971
# 2018-10-31     FB  163.030  165.8800  161.260  162.44  26407677
# 2018-11-30     FB  151.520  152.7500  149.350  151.75  25640786
# 2018-12-31     FB  143.000  143.6799  140.760  141.09  24819226

# %%
import statistics as stat

#Finding the mean of the open price column

openCols = fngCsv['open']
mean = stat.mean(openCols)
print(mean)
# Out:
# 687.1480807968128

# %%
#Finding the Highest price in the data set

maxPrice = fngCsv['high'].max()
maxPrice
# Out:
# 2050.5

# %%
#Finding the Lowest price in the data set

minPrice = fngCsv['low'].min()
minPrice
# Out:
# 123.02

# %%
#Finding the mean of the closing price
closeCols = fngCsv['close']
newMean = stat.mean(closeCols)
print(newMean)
# Out:
# 686.5477534661354

# %%
fngCsv['volume'].sum()
# Out:
# 20223555523

# %%
#Building a crosstab between the magType and tsunami column

crossTab = pd.crosstab(index = earthquakesdf['tsunami'], 
                       columns = earthquakesdf['magType'], 
                       values=earthquakesdf['mag'], aggfunc='max')
crossTab
# Out:
# magType   mb  mb_lg    md   mh   ml  ms_20    mw  mwb  mwr  mww
# tsunami
# 0        5.6    3.5  4.11  1.1  4.2    NaN  3.83  5.8  4.8  6.0
# 1        6.1    NaN   NaN  NaN  5.1    5.7  4.41  NaN  NaN  7.5

# %%
"""
Applying the 60D rolling function using the same aggregations found in no. 3
for each OHLC and ticker using rolling() and agg()

"""
rollStats = fngCsv.groupby('ticker').apply(lambda x: x.rolling(window=60).agg({
    'open': 'mean',
    'high': 'max',
    'low': 'min',
    'close': 'mean',
    'volume': 'sum'
}))

rollStats
# Out:
# C:\Users\Karl Josef Malaki\AppData\Local\Temp\ipykernel_21184\2485233264.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   rollStats = fngCsv.groupby('ticker').apply(lambda x: x.rolling(window=60).agg({
#                          open      high     low       close       volume
# ticker date
# AAPL   2018-01-02         NaN       NaN     NaN         NaN          NaN
#        2018-01-03         NaN       NaN     NaN         NaN          NaN
#        2018-01-04         NaN       NaN     NaN         NaN          NaN
#        2018-01-05         NaN       NaN     NaN         NaN          NaN
#        2018-01-08         NaN       NaN     NaN         NaN          NaN
# ...                       ...       ...     ...         ...          ...
# NFLX   2018-12-24  306.018050  386.7999  233.68  303.239833  811001766.0
#        2018-12-26  303.596050  386.7999  231.23  301.232167  818289623.0
#        2018-12-27  301.500383  386.7999  231.23  299.134417  822148280.0
#        2018-12-28  299.393050  380.9300  231.23  297.116750  824496849.0
#        2018-12-31  297.420217  380.0000  231.23  295.293583  832207164.0
#
# [1255 rows x 5 columns]

# %%
#Creating pivot table

pivotTable = pd.pivot_table(data= fngCsv, index= ['ticker'])
pivotTable
# Out:
#               close         high          low         open        volume
# ticker
# AAPL     186.986218   188.906858   185.135729   187.038674  3.402145e+07
# AMZN    1641.726175  1662.839801  1619.840398  1644.072669  5.649563e+06
# FB       171.510936   173.615298   169.303110   171.454424  2.768798e+07
# GOOG    1113.225139  1125.777649  1101.001594  1113.554104  1.742645e+06
# NFLX     319.290299   325.224583   313.187273   319.620533  1.147030e+07

# %%
#Calculating the z-scores of NFLX
import numpy as np
import scipy.stats as stats

#
pivotTable.loc['NFLX', ['close', 'high', 'low', 'open']].apply(lambda x : stats.zscore(x))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[54], line 6
#       3 import scipy.stats as stats
#       5 #
# ----> 6 pivotTable.loc['NFLX', ['close', 'high', 'low', 'open']].apply(lambda x : stats.zscore(x))
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[54], line 6, in <lambda>(x)
#       3 import scipy.stats as stats
#       5 #
# ----> 6 pivotTable.loc['NFLX', ['close', 'high', 'low', 'open']].apply(lambda x : stats.zscore(x))
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\scipy\stats\_stats_py.py:2941, in zscore(a, axis, ddof, nan_policy)
#    2859 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2860     """
#    2861     Compute the z score.
#    2862
#    (...)
#    2939            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2940     """
# -> 2941     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\scipy\stats\_stats_py.py:3105, in zmap(scores, compare, axis, ddof, nan_policy)
#    3103         isconst = np.apply_along_axis(_isconst, axis, a)
#    3104 else:
# -> 3105     mn = a.mean(axis=axis, keepdims=True)
#    3106     std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    3107     # The intent is to check whether all elements of `a` along `axis` are
#    3108     # identical. Due to finite precision arithmetic, comparing elements
#    3109     # against `mn` doesn't work. Previously, this compared elements to
#    3110     # `_first`, but that extracts the element at index 0 regardless of
#    3111     # whether it is masked. As a simple fix, compare against `min`.
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\numpy\core\_methods.py:106, in _mean(a, axis, dtype, out, keepdims, where)
#     102 arr = asanyarray(a)
#     104 is_float16_result = False
# --> 106 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     107 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     108     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\numpy\core\_methods.py:77, in _count_reduce_items(arr, axis, keepdims, where)
#      75     items = 1
#      76     for ax in axis:
# ---> 77         items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      78     items = nt.intp(items)
#      79 else:
#      80     # TODO: Optimize case when `where` is broadcast along a non-reduction
#      81     # axis and full sum is more excessive than needed.
#      82
#      83     # guarded to protect circular imports
#
# AxisError: axis 0 is out of bounds for array of dimension 0

# %%
#Since mine kept on saying that there were no data found (dimension 0) I tried getting the zscores of the OHLC for each ticker
zScores = pivotTable.loc[:, ['close', 'high', 'low', 'open']].apply(lambda x : stats.zscore(x))
zScores #Stored the zscore data here
# Out:
#            close      high       low      open
# ticker
# AAPL   -0.845835 -0.847010 -0.844539 -0.845665
# AMZN    1.617265  1.618472  1.615403  1.618121
# FB     -0.872037 -0.872589 -0.871685 -0.872017
# GOOG    0.722431  0.720115  0.725803  0.721035
# NFLX   -0.621824 -0.618988 -0.624982 -0.621474

# %%
#After that I showed the row in which all the OHLC of the NFLX ticker has its own zscores.
zNFLX = zScores.loc['NFLX']
zNFLX
# Out:
# close   -0.621824
# high    -0.618988
# low     -0.624982
# open    -0.621474
# Name: NFLX, dtype: float64

# %%
#Creating a new dataframe

newD = {'ticker' : 'FB' , 
        'date' : ['2018-07-25' , '2018-03-19' , '2018-03-20'], 
        'event' : ['Disappointing user growth announced after close' , 'Cambridge Analytica Story', 'FTC investigation']}
newDataFrame = pd.DataFrame(data= newD).set_index(['date' , 'ticker'])
newDataFrame
# Out:
#                                                              event
# date       ticker
# 2018-07-25 FB      Disappointing user growth announced after close
# 2018-03-19 FB                            Cambridge Analytica Story
# 2018-03-20 FB                                    FTC investigation

# %%
newDataFrame.iloc['ticker']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 newDataFrame.iloc['ticker']
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Karl Josef Malaki\AppData\Local\Programs\Python\Python312\Lib\site-packages\Data Science\.venv\Lib\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# -> 1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
newDataFrame
# Out:
#                                                              event
# date       ticker
# 2018-07-25 FB      Disappointing user growth announced after close
# 2018-03-19 FB                            Cambridge Analytica Story
# 2018-03-20 FB                                    FTC investigation

# %%
#Using Outer join
resultDf = pd.merge(newDataFrame, rollStats, on = 'ticker', how = 'outer')
resultDf
# Out:
#        event        open      high     low       close       volume
# ticker
# AAPL     NaN         NaN       NaN     NaN         NaN          NaN
# AAPL     NaN         NaN       NaN     NaN         NaN          NaN
# AAPL     NaN         NaN       NaN     NaN         NaN          NaN
# AAPL     NaN         NaN       NaN     NaN         NaN          NaN
# AAPL     NaN         NaN       NaN     NaN         NaN          NaN
# ...      ...         ...       ...     ...         ...          ...
# NFLX     NaN  306.018050  386.7999  233.68  303.239833  811001766.0
# NFLX     NaN  303.596050  386.7999  231.23  301.232167  818289623.0
# NFLX     NaN  301.500383  386.7999  231.23  299.134417  822148280.0
# NFLX     NaN  299.393050  380.9300  231.23  297.116750  824496849.0
# NFLX     NaN  297.420217  380.0000  231.23  295.293583  832207164.0
#
# [1757 rows x 6 columns]

# %%
transFormedData = fngCsv.groupby('ticker').transform(lambda x: x / x.iloc[0])

print(transFormedData)
# Out:
#                 open      high       low     close    volume
# date
# 2018-01-02  1.000000  1.000000  1.000000  1.000000  1.000000
# 2018-01-03  1.023638  1.017623  1.021290  1.017914  0.930292
# 2018-01-04  1.040635  1.025498  1.036889  1.016040  0.764707
# 2018-01-05  1.044518  1.029298  1.041566  1.029931  0.747830
# 2018-01-08  1.053579  1.040313  1.049451  1.037813  0.991341
# ...              ...       ...       ...       ...       ...
# 2018-12-24  0.928993  0.940578  0.928131  0.916638  1.285047
# 2018-12-26  0.943406  0.974750  0.940463  0.976019  1.917695
# 2018-12-27  0.970248  0.978396  0.953857  0.980169  1.704782
# 2018-12-28  1.001221  0.989334  0.988395  0.973784  1.142383
# 2018-12-31  1.002499  0.986653  0.979296  0.972404  1.206986
#
# [1255 rows x 5 columns]
